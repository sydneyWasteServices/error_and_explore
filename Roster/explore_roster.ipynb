# %%
import pandas as pd
import numpy as np

# %%
# Weekday
PATH = "/media/sf_BLOB_STORAGE/Roster/Weekdays/Copy of Drivers and Rosters MON 01.03 to TUE 02.03.xlsx"
PATH = "/media/sf_BLOB_STORAGE/Roster/Weekdays/Copy of Drivers and Rosters THU 08.04 to FRI 09.04.xlsx"
df = pd.read_excel(PATH)

# %%
df.iloc[:,0].str.lower()

# When Visy is same column as 
if df[df.iloc[:,0].str.lower().eq("visy")].any(True).values:
    visyidx = df[df.iloc[:,0].str.lower().eq("visy")].index[0]
    
    if df[df.iloc[:,0].str.lower().eq("university")].any(True).values:
        uosidx = df[df.iloc[:,0].str.lower().eq("university")].index[0]
#       Plus 1 to capture only Rocky Li
        visy_df = df.iloc[visyidx+1:uosidx]
    
visy_df
# df.loc[df.iloc[:,0] == "day runs"]
# lookup for Word => Day Runs 
# df[df.iloc[:,0].str.lower().eq("day runs")].index[0]
# .eq("visy")

    

#     df[].index[0]
# Identify Visy Exist
# condition 1 - Col 1 has visy / Col 2 is nan / col 3 is nan

# condition 2 ricky li / john justice are definitly in visy
# Out:
#       NIGHT RUNS    THURSDAY Unnamed: 2 2021-04-08 00:00:00
# 28      RICKY LI      NIWPR1    XPL 658                 NaN
# 29  JOHN JUSTICE  NIWPR2/CBK   BY 46 TO                 NaN

# %%
df
# Out:
#         NIGHT RUNS                            THURSDAY             Unnamed: 2  \
# 0       ADONIS AKL                                 RLE               CL 98 LU
# 1       PAUL NEVIN                                 BR2               CJ 65 PS
# 2   KEVEN SHEATHER                                 RL8               XN 62 UD
# 3       PETER DINH                                 RED               XN 19 IN
# 4       PETER DINH                                 RLR               XN 19 IN
# 5      ALAN WALDEN                                 RLC               XN 65 IJ
# 6         DAY RUNS                              FRIDAY                    NaN
# 7      JOHNNY RUHR                                 BR1               XN 75 OS
# 8    TAIT MITCHELL                                 BR3               XN 06 OJ
# 9     GARY ROBERTS                                 RL1               CN 41 XN
# 10       ALBERT DO                                 RL2               XN 23 KQ
# ...
