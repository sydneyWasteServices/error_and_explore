# %%
import pandas as pd
import numpy as np

# %%
PATH = "/media/sf_BLOB_STORAGE/Veolia_suez_Ton_Report/suez_csv/all_8.4.2021_.csv"
df = pd.read_csv(PATH)

# %%
df.head()
# Out:
#          Date       Docket                          Location  \
# 0  2020-12-31  BC130038667  Belrose WMC Transfer & Recycling
# 1  2020-12-31  AR110094879                      Artarmon WMC
# 2  2020-12-31  DR150040229                    Davis Road WMC
# 3  2021-01-01  AU120081046                        Auburn WMC
# 4  2021-01-01  JG180091009                   Jacks Gully AWT
#
#              1st Weigh            2nd Weigh Stored tare?    Rego  \
# 0  2020-12-31 09:03:05  2020-12-31 09:16:00            N  CN41XN
# 1  2020-12-31 10:42:12  2020-12-31 10:51:15            N  XN44QZ
# 2  2020-12-31 09:46:56  2020-12-31 09:47:13            N  XN72MK
# 3  2021-01-01 06:51:56  2021-01-01 06:58:28            N  XN71FD
# 4  2021-01-01 07:12:10  2021-01-01 07:21:43            N  XN25GD
#
#    Account code  Product Code Product name  Gross (t)  Tare (t)  Net (t)  \
# 0     5209148.0        8073.0  Mixed Waste      17.58     13.30     4.28
# ...

# %%
df.tail(50)
# Out:
#            Date       Docket                          Location  \
# 931  2021-03-30  DR150055223                    Davis Road WMC
# 932  2021-03-30  DR150055228                    Davis Road WMC
# 933  2021-03-31  AU120106643                        Auburn WMC
# 934  2021-03-31  AR110124134                      Artarmon WMC
# 935  2021-03-31  AU120106651                        Auburn WMC
# 936  2021-03-31  AU120106660                        Auburn WMC
# 937  2021-03-31  AU120106662                        Auburn WMC
# 938  2021-03-31  AU120106663                        Auburn WMC
# 939  2021-03-31  AR110124175                      Artarmon WMC
# 940  2021-03-31  SH230144835                   Seven Hills WMC
# 941  2021-03-31  AR110124189                      Artarmon WMC
# 942  2021-03-31  AU120106731                        Auburn WMC
# 943  2021-03-31  AR110124255                      Artarmon WMC
# 944  2021-03-31  AU120106745                        Auburn WMC
# ...
